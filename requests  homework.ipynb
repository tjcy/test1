# %%
kaifang_file = 'C:\\Users\\admi\\Desktop\\kaifangX.txt'
email_file = 'C:\\Users\\admi\\Desktop\\a.txt'
kaifang_file_open=open(kaifang_file,'r',encoding='utf-8',errors='ignore')
email_file_open=open(email_file,'a',encoding='utf-8',errors='ignore')
for i in range(10000):
    try:
        email = kaifang_file_open.readline().split(',')[9] 
        email_file_open.write(email)
    except Exception as e:
        print(e)
        print('未获取到数据')
kaifang_file_open.close()
email_file_open.close()
# Out:
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
# list index out of range
# 未获取到数据
